# %% [markdown]
# # Bristol Myers Squibb ETL
# ---
# ## The purpose of this script is to scrape research locations from BMS's website.

# %%
# Dependencies

# Web scraping dependencies
from bs4 import BeautifulSoup

# Asynchronous scraping dependencies
import time
from selenium import webdriver

# Database deployment dependencies
import pymongo

# Data Dependencies
import pandas as pd

# %% [markdown]
# # Create MongoDB connection

# %%
# Set up connection to localhost and connect to a client
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Create a new database
db = client.clinical_trial_db

# Create a new collection and reset the collection
collection = db.bristol_myers_squibb
db.drop_collection(collection)
# Out:
# {'ok': 0.0,
#  'errmsg': 'ns not found',
#  'code': 26,
#  'codeName': 'NamespaceNotFound'}

# %% [markdown]
# # Extract HTML Site Data From BMS

# %%
# Chromedriver set-up
executable_path = {'executable_path': 'chromedriver.exe'}
browser = webdriver.Chrome(**executable_path)
url = 'https://www.bmsstudyconnect.com/content/studyconnect/us/en/sites-list.html?id=NCT01357668&language=en&geo_lati=&geo_long=&location='
browser.get(url)

# 20 second time delay is so that the page can load and all information can be scraped
time.sleep(20)

# Scrape the html on the site after the timer is done
html = browser.page_source
soup = BeautifulSoup(html, 'html.parser')

# set the class definition to only find divs that match a specific kind of class
research_divs = soup.find_all("div", {"class": "grid-x grid-margin-x bmssc-result-item bmssc-site-result"})

# find the trial_id from the page as well
trial_id = soup.find("span", id="trail-id-each").text

# %% [markdown]
# # Parse HTML and load to database

# %%
# Loop through returned results in research_divs
# These list boxes contain the research site locations and their current recruitment status
for result in research_divs:
    # Error handling
    # Handles cases where HTML atributes do not exist within a particular result in the research_divs list
    try:
        # Return the location of the research site
        location = result.find('div', class_ = "bmssc-type-medium--alternate bmssc-color-dark-grey").text
        
        # Case 1: The research site is currently Recruiting
        is_recruiting = result.find('div', class_="hide-for-medium bmssc-status--indicator is-recruiting active").text
        
        # Modify strings
        is_recruiting = is_recruiting.replace(" ", "")
        is_recruiting = is_recruiting.replace("\n", "")
        
        # update location_dict
        location_dict = { trial_id: { "status" : is_recruiting, "location": location} }

        # insert into the collection
        collection.insert_one(location_dict)
    
    # Make exception for html attribute not existing
    except AttributeError as e:
        # Case 2: The research site is not recruiting yet 
        not_recruiting = result.find('div', class_="hide-for-medium bmssc-status--indicator is-notyetrecruiting active").text
        
        # Modify strings
        not_recruiting = not_recruiting.replace(" ", "")
        not_recruiting = not_recruiting.replace("\n", "")
        
        # update location_dict
        location_dict = { trial_id: { "status" : not_recruiting, "location": location} }
        
        # insert into the collection
        collection.insert_one(location_dict)

# %%
# Display items in MongoDB collection
listings = db.bristol_myers_squibb.find()

for listing in listings:
    print(listing)
# Out:
# {'_id': ObjectId('5cb212f3c1a0796378a1d82e'), 'IM101-240': {'status': 'Recruiting', 'location': 'Little Rock, Arkansas 72202'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1
}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d84f'), 'IM101-240': {'status': 'Recruiting', 'location': 'Bad Bramstedt 24576'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d850'), 'IM101-240': {'status': 'Recruiting', 'location': 'Montreal, Quebec H3H 1P3'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d851'), 'IM101-240': {'status': 'Recruiting', 'location': 'Toronto, Ontario M5G 1X8'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d852'), 'IM101-240': {'status': 'Recruiting', 'location': 'Halifax, Nova Scotia B3K 6R8'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d853'), 'IM101-240': {'status': 'Recruiting', 'location': 'Vancouver, British Columbia V6H 3V4'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d854'), 'IM101-240': {'status': 'Recruiting', 'location': 'São Paulo 04038-001'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d855'), 'IM101-240': {'status': 'Recruiting', 'location': 'Rio de Janeiro 21941-912'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d856'), 'IM101-240': {'status': 'Recruiting', 'location': 'Campinas 13078500'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d857'), 'IM101-240': {'status': 'Recruiting', 'location': 'Botucatu 18618-970'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d858'), 'IM101-240': {'status': 'Recruiting', 'location': 'Innsbruck A-6020'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d859'), 'IM101-240': {'status': 'Recruiting', 'location': 'Bregenz A-6900'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d85a'), 'IM101-240': {'status': 'Recruiting', 'location': 'Milwaukee, Wisconsin 53201'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d85b'), 'IM101-240': {'status': 'Recruiting', 'location': 'Salt Lake City, Utah 84112'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d85c'), 'IM101-240': {'status': 'Recruiting', 'location': 'Austin, Texas 78701'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d85d'), 'IM101-240': {'status': 'Recruiting', 'location': 'Pittsburgh, Pennsylvania 15224'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d85e'), 'IM101-240': {'status': 'Recruiting', 'location': 'Philadelphia, Pennsylvania 19134'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d85f'), 'IM101-240': {'status': 'Recruiting', 'location': 'Portland, Oregon 97227'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d860'), 'IM101-240': {'status': 'Recruiting', 'location': 'Cleveland, Ohio 44195'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d861'), 'IM101-240': {'status': 'Recruiting', 'location': 'Cincinnati, Ohio 45229'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d862'), 'IM101-240': {'status': 'Recruiting', 'location': 'Charlotte, North Carolina 28207'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d863'), 'IM101-240': {'status': 'Recruiting', 'location': 'New Brunswick, New Jersey 08901'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d864'), 'IM101-240': {'status': 'Recruiting', 'location': 'Livingston, New Jersey 07039'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d865'), 'IM101-240': {'status': 'NotYetRecruiting', 'location': 'Napoli 80138'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d866'), 'IM101-240': {'status': 'NotYetRecruiting', 'location': 'Nashville, Tennessee 37203'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d867'), 'IM101-240': {'status': 'NotYetRecruiting', 'location': 'Philadelphia, Pennsylvania 19104'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d868'), 'IM101-240': {'status': 'NotYetRecruiting', 'location': 'Kansas City, Missouri 64108'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d869'), 'IM101-240': {'status': 'NotYetRecruiting', 'location': 'Gainesville, Florida 32611-0158'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d86a'), 'IM101-240': {'status': 'NotYetRecruiting', 'location': 'Tromso 9019'}}
# {'_id': ObjectId('5cb212f3c1a0796378a1d86b'), 'IM101-240': {'status': 'NotYetRecruiting', 'location': 'Torino 10126'}}
